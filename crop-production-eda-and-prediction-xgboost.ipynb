# %% [markdown]
# # About Dataset <br>
# This dataset encompasses extensive information on crop production in India, spanning multiple years and offering insights into agricultural trends and patterns. The dataset consists of over 246,000 records, capturing a wide array of variables related to crop production, and is intended to facilitate advanced analyses such as predictive modeling and the extraction of key insights for stakeholders in the agri-food sector.
#
# ### Temporal Coverage:<br>
#
# The dataset covers multiple years, providing a longitudinal view of crop production trends in India. This temporal dimension is crucial for analyzing changes over time and understanding long-term patterns.<br>
#
# ### Geographical Scope:<br>
#
# Data is collected across various states and regions of India, reflecting the diverse agricultural landscape of the country. Regional variations in crop production can be analyzed to identify local factors affecting yields.<br>
#
#
# ### Crop Types:<br>
#
# The dataset includes information on various crop types grown across different regions. This classification allows for detailed analysis of specific crops, their production levels, and their sensitivity to various factors.<br>
#
#
# ### Production Metrics:<br>
#
# Metrics related to crop production such as yield (e.g., tons per hectare), total production volume, and harvested area are included. These metrics are essential for evaluating productivity and efficiency.<br>
#
# ### Data Quality and Completeness:<br>
#
# The dataset is likely to include a mix of structured and unstructured data. Data quality may vary, and preprocessing steps such as cleaning and normalization may be necessary to ensure accurate analyses.<br>
#
#
# ### Applications and Objectives:<br>
#
# #### Predictive Modeling:<br>
#
# The primary goal of analyzing this dataset is to develop predictive models for crop production. By leveraging historical data, machine learning algorithms can forecast future production levels and identify potential risks.<br>
#
#
# #### Insight Extraction:<br>
#
# The dataset provides an opportunity to uncover key indicators and metrics that significantly influence crop production. Insights can help stakeholders make informed decisions regarding crop management, resource allocation, and policy formulation.<br>
#
#
# #### Trend Analysis:<br>
#
# Longitudinal analysis of the data can reveal trends and patterns in crop production, helping to understand how factors such as technological advancements, policy changes, and environmental conditions affect agriculture.<br>
#
#
# #### Stakeholder Collaboration:<br>
#
# The dataset supports the development of collaboration platforms that connect various stakeholders in the agri-food sector. By integrating data from multiple sources, stakeholders can collaborate more effectively to address challenges and optimize production.<br>
#
#
# #### Key Features:<br>
#
# 1. **State_Name**: Represents the name of the state in India where the crop data was recorded.<br>
# 2. **District_Name**: Specifies the district within the state where the crop data was collected.<br>
# 3. **Crop_Year**: Indicates the year in which the crop was harvested.<br>
# 4. **Season**: Denotes the agricultural season (e.g., Kharif, Rabi) during which the crop was grown.<br>
# 5. **Crop**: Identifies the type of crop that was cultivated.<br>
# 6. **Area**: Represents the total land area used for cultivating the crop.<br>
# 7. **Production**: Indicates the total quantity of the crop produced from the specified area.<br>

# %% [markdown]
# # Import Necessary Libraies

# %%
# %pip install -q catboost xgboost lightgbm kagglehub

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from lightgbm import LGBMRegressor
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform

import warnings 

warnings.filterwarnings("ignore")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: C:\Users\georg\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# # Load our Data

# %%
import os
import kagglehub

# Set up data directory
data_dir = "./data/kaggle_datasets"
os.makedirs(data_dir, exist_ok=True)

# Download dataset from Kaggle if not already present
csv_path = os.path.join(data_dir, "Crop Production data.csv")

if not os.path.exists(csv_path):
    print("Downloading dataset from Kaggle...")
    path = kagglehub.dataset_download("srinivas1/crop-production-data-india")
    print(f"Dataset downloaded to: {path}")
else:
    print(f"Dataset already exists at: {csv_path}")

# Load the data
df = pd.read_csv(csv_path)
# Out:
# Downloading dataset from Kaggle...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kagglehub\exceptions.py:66, in kaggle_api_raise_for_status(response, resource_handle)
#      65 try:
# ---> 66     response.raise_for_status()
#      67 except requests.HTTPError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/datasets/view/srinivas1/crop-production-data-india
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# Cell In[4], line 13
#      11 if not os.path.exists(csv_path):
#      12     print("Downloading dataset from Kaggle...")
# ---> 13     path = kagglehub.dataset_download("srinivas1/crop-production-data-india")
#      14     print(f"Dataset downloaded to: {path}")
#      15 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kagglehub\datasets.py:43, in dataset_download(handle, path, force_download)
#      41 h = parse_dataset_handle(handle)
#      42 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 43 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      44 return path
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kagglehub\resolver.py:29, in Resolver.__call__(self, handle, path, force_download)
#      15 def __call__(
#      16     self, handle: T, path: Optional[str] = None, *, force_download: Optional[bool] = False
#      17 ) -> tuple[str, Optional[int]]:
#      18     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      19
#      20     Args:
#    (...)
#      27         Some cases where version number might be missing: Competition datasource, API-based models.
#      28     """
# ---> 29     path, version = self._resolve(handle, path, force_download=force_download)
#      31     # Note handles are immutable, so _resolve() could not have altered our reference
#      32     register_datasource_access(handle, version)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kagglehub\http_resolver.py:107, in DatasetHttpResolver._resolve(self, h, path, force_download)
#     104 api_client = KaggleApiV1Client()
#     106 if not h.is_versioned():
# --> 107     h = h.with_version(_get_current_version(api_client, h))
#     109 dataset_path = load_from_cache(h, path)
#     110 if dataset_path and not force_download:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kagglehub\http_resolver.py:290, in _get_current_version(api_client, h)
#     287     return json_response[MODEL_INSTANCE_VERSION_FIELD]
#     289 elif isinstance(h, DatasetHandle):
# --> 290     json_response = api_client.get(_build_get_dataset_url_path(h), h)
#     291     if DATASET_CURRENT_VERSION_FIELD not in json_response:
#     292         msg = f"Invalid GetDataset API response. Expected to include a {DATASET_CURRENT_VERSION_FIELD} field"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kagglehub\clients.py:139, in KaggleApiV1Client.get(self, path, resource_handle)
#     132 url = self._build_url(path)
#     133 with requests.get(
#     134     url,
#     135     headers={"User-Agent": get_user_agent()},
#     136     auth=self._get_auth(),
#     137     timeout=(DEFAULT_CONNECT_TIMEOUT, DEFAULT_READ_TIMEOUT),
#     138 ) as response:
# --> 139     kaggle_api_raise_for_status(response, resource_handle)
#     140     self._check_for_version_update(response)
#     141     return response.json()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kagglehub\exceptions.py:106, in kaggle_api_raise_for_status(response, resource_handle)
#      97     message = (
#      98         f"{response.status_code} Client Error."
#      99         "\n\n"
#    (...)
#     102         "Please make sure you specified the correct resource identifiers."
#     103     )
#     105 # Default handling
# --> 106 raise KaggleApiHTTPError(message, response=response) from e
#
# KaggleApiHTTPError: 403 Client Error.
#
# You don't have permission to access resource at URL: https://www.kaggle.com/datasets/srinivas1/crop-production-data-india. The server reported the following issues: Permission 'datasets.get' was denied
# Please make sure you are authenticated if you are trying to access a private resource or a resource requiring consent.

# %%
df.head()
# Out:
#             State_Name    District_Name  Crop_Year       Season  \
# 0  ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 1  ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 2  ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 3  ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year
# 4  ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %% [markdown]
# # Check of Data

# %%
print("Number of Columns:", df.shape[1])
print("Number of Rows:", df.shape[0])
# Out:
# Number of Columns: 7
# Number of Rows: 246091

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
print("Number of Duplicates: ", df.duplicated().sum())
# Out:
# Number of Duplicates:  0

# %% [markdown]
# # EDA

# %%
des = df.describe().transpose()
des.style.background_gradient()
# Out:
# <style type="text/css">
# #T_733c3_row0_col0, #T_733c3_row0_col3, #T_733c3_row0_col4, #T_733c3_row0_col5, #T_733c3_row1_col0, #T_733c3_row2_col1, #T_733c3_row2_col2, #T_733c3_row2_col6, #T_733c3_row2_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_733c3_row0_col1, #T_733c3_row0_col2, #T_733c3_row0_col6, #T_733c3_row0_col7, #T_733c3_row1_col2, #T_733c3_row1_col3, #T_733c3_row1_col4, #T_733c3_row1_col5, #T_733c3_row2_col0, #T_733c3_row2_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_733c3_row1_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_733c3_row1_col6 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_733c3_row1_col7, #T_733c3_row2_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_733c3_row2_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# </style>
# <table id="T_733c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_733c3_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_733c3_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_733c3_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_733c3_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_733c3_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_733c3_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_733c3_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_733c3_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_733c3_level0_row0" class="row_heading level0 row0" >Crop_Year</th>
#       <td id="T_733c3_row0_col0" class="data row0 col0" >246091.000000</td>
#       <td id="T_733c3_row0_col1" class="data row0 col1" >2005.643018</td>
#       <td id="T_733c3_row0_col2" class="data row0 col2" >4.952164</td>
#       <td id="T_733c3_row0_col3" class="data row0 col3" >1997.000000</td>
#       <td id="T_733c3_row0_col4" class="data row0 col4" >2002.000000</td>
#       <td id="T_733c3_row0_col5" class="data row0 col5" >2006.000000</td>
#       <td id="T_733c3_row0_col6" class="data row0 col6" >2010.000000</td>
#       <td id="T_733c3_row0_col7" class="data row0 col7" >2015.000000</td>
#     </tr>
#     <tr>
#       <th id="T_733c3_level0_row1" class="row_heading level0 row1" >Area</th>
#       <td id="T_733c3_row1_col0" class="data row1 col0" >246091.000000</td>
#       <td id="T_733c3_row1_col1" class="data row1 col1" >12002.820864</td>
#       <td id="T_733c3_row1_col2" class="data row1 col2" >50523.404019</td>
#       <td id="T_733c3_row1_col3" class="data row1 col3" >0.040000</td>
#       <td id="T_733c3_row1_col4" class="data row1 col4" >80.000000</td>
#       <td id="T_733c3_row1_col5" class="data row1 col5" >582.000000</td>
#       <td id="T_733c3_row1_col6" class="data row1 col6" >4392.000000</td>
#       <td id="T_733c3_row1_col7" class="data row1 col7" >8580100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_733c3_level0_row2" class="row_heading level0 row2" >Production</th>
#       <td id="T_733c3_row2_col0" class="data row2 col0" >242361.000000</td>
#       <td id="T_733c3_row2_col1" class="data row2 col1" >582503.442251</td>
#       <td id="T_733c3_row2_col2" class="data row2 col2" >17065813.172410</td>
#       <td id="T_733c3_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_733c3_row2_col4" class="data row2 col4" >88.000000</td>
#       <td id="T_733c3_row2_col5" class="data row2 col5" >729.000000</td>
#       <td id="T_733c3_row2_col6" class="data row2 col6" >7023.000000</td>
#       <td id="T_733c3_row2_col7" class="data row2 col7" >1250800000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(25, 16))
for i, feature in enumerate(df.select_dtypes(include="object").columns):
    counts = df[feature].value_counts().head(10)
    plt.subplot(2, 2, i+1)
    sns.barplot(x=counts.values, y=counts.index, palette='viridis')
    plt.title(f"{feature}")
    plt.ylabel(f"{feature}")
    plt.xlabel("Count")
plt.show()

# %%
group_by_year = df.groupby("Crop_Year").sum()

plt.figure(figsize=(10, 6))
sns.lineplot(data=group_by_year)
plt.title('Trend of Production (1997-2015)')
plt.xlabel('Year')
plt.ylabel('Production')
plt.xticks(rotation=45)
plt.show()

# %%
group_by_crop = df.groupby("Crop")["Production"].median().reset_index()

plt.figure(figsize=(25, 25))
sns.barplot(x=group_by_crop["Crop"], y=group_by_crop["Production"], palette='viridis')
plt.title("How the Production varies across different Crops", fontsize=26)
plt.xlabel("Crop", fontsize=26)
plt.ylabel("Production", fontsize=26)
plt.xticks(rotation=90) 
plt.show()

# %%
group_by_crop = df.groupby("Season")["Production"].median().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x=group_by_crop["Season"], y=group_by_crop["Production"], palette='viridis')
plt.title("Crops produced during different Seasons.")
plt.xlabel("Season")
plt.ylabel("Production")
plt.xticks(rotation=45) 
plt.show()

# %%
group_by_crop = df.groupby("District_Name")["Production"].median().reset_index().head(25)

plt.figure(figsize=(15, 10))
sns.barplot(x=group_by_crop["District_Name"], y=group_by_crop["Production"], palette='viridis')
plt.title("compare the production across different first 25 States", fontsize=20)
plt.xlabel("State",  fontsize=14)
plt.ylabel("Production",  fontsize=14)
plt.xticks(rotation=45) 
plt.show()

# %%
plt.figure(figsize=(10, 6))
for i, feature in enumerate(df.select_dtypes(include="number").columns):
    plt.subplot(2, 2, i+1)
    sns.boxenplot(data=df, x=feature)
plt.tight_layout()

# %% [markdown]
# # Encoding

# %%
encoder = LabelEncoder()

df["State_Name"] = encoder.fit_transform(df["State_Name"])
df["District_Name"] = encoder.fit_transform(df["District_Name"])
df["Season"] = encoder.fit_transform(df["Season"])
df["Crop"] = encoder.fit_transform(df["Crop"])

# %% [markdown]
# # Correlation

# %%
corr = df.corr()
mask_ut = np.triu(np.ones(corr.shape)).astype(np.bool_)

plt.figure(figsize=(15,10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="icefire", mask=mask_ut)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %%
def distance(data, label = ''):
    corr = data.corr(method = 'spearman')
    dist_linkage = linkage(squareform(1 - abs(corr)), 'complete')
    
    plt.figure(figsize = (10, 8), dpi = 300)
    dendro = dendrogram(dist_linkage, labels=data.columns, leaf_rotation=90)
    plt.title(f'Feature Distance in {label} Dataset', weight = 'bold', size = 20)
    plt.show()

# %%
distance(corr)

# %% [markdown]
# # Missing Values Treatment

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Outliers Treatment

# %%
q1 = df["Area"].quantile(0.25)
q3 = df["Area"].quantile(0.75)
iqr = q3 - q1

upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)

df = df.loc[(df["Area"] > lower_limit) & (df["Area"] < upper_limit)]

# %% [markdown]
# # Scaling

# %%
X = df.drop("Production", axis=1)
y = df["Production"]

# %%
standard_scaler = StandardScaler()

X = standard_scaler.fit_transform(X)

# %%
min_max_scaler = MinMaxScaler()

y = np.array(y)

y = min_max_scaler.fit_transform(y.reshape(-1, 1))

# %% [markdown]
# # Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((161944, 6), (161944, 1), (40486, 6), (40486, 1))

# %% [markdown]
# # Model Bulding

# %%
param = {
    'n_estimators': 300,
    'learning_rate': 0.1,
    'max_depth': 7,
    'subsample': 1.0,
    'colsample_bytree': 1.0,
    'gamma': 0
}

reg = XGBRegressor(random_state=42, **param)

# %%
# param_grid = {
#     'n_estimators': [100, 200, 300],
#     'learning_rate': [0.1, 0.01, 0.001],
#     'max_depth': [3, 5, 7],
#     'subsample': [0.6, 0.8, 1.0],
#     'colsample_bytree': [0.6, 0.8, 1.0],
#     'gamma': [0, 0.1, 0.2],
# }

# grid_search = GridSearchCV(estimator=reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=5, verbose=1, n_jobs=-1)

# grid_search.fit(x_train, y_train)

# print("Best Parameters:", grid_search.best_params_)

# best_model = grid_search.best_estimator_

reg.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=300, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# # Evaluation

# %%
y_pred = reg.predict(x_test)

# %%
print("MAE: ", mean_absolute_error(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
print("R2-score: ", f"{(r2_score(y_test, y_pred) * 100):0.1f}", "%")
# Out:
# MAE:  0.00011007623237860008
# MSE:  5.665328374001729e-06
# R2-score:  92.1 %

# %%
fig, ax = plt.subplots(figsize = (12, 6))

y_test = y_test.flatten() if hasattr(y_test, "flatten") else y_test
y_pred = y_pred.flatten() if hasattr(y_pred, "flatten") else y_pred

sns.scatterplot(x = y_test, y = y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color = 'red')
ax.set_title(f"Real x Predito (R2 Score: {r2_score(y_test, y_pred):.4f})", fontsize = 15, pad = 10, loc = 'left')
ax.set_xlabel("Real", fontsize = 8)
ax.set_ylabel("Previsto", fontsize = 8)
plt.show()

# %%
import gradio as gr

# %pip install -q gradio


def predict_production(state_name, district_name, crop_year, season, crop, area):
    # Create input dataframe
    input_data = pd.DataFrame({
        'State_Name': [state_name],
        'District_Name': [district_name],
        'Crop_Year': [crop_year],
        'Season': [season],
        'Crop': [crop],
        'Area': [area]
    })
    
    # Apply label encoding (use the same encoder fitted on training data)
    input_data['State_Name'] = encoder.transform([state_name])[0]
    input_data['District_Name'] = encoder.transform([district_name])[0]
    input_data['Season'] = encoder.transform([season])[0]
    input_data['Crop'] = encoder.transform([crop])[0]
    
    # Scale the input
    input_scaled = standard_scaler.transform(input_data)
    
    # Make prediction
    prediction_scaled = reg.predict(input_scaled)
    
    # Inverse transform to get actual production value
    prediction = min_max_scaler.inverse_transform(prediction_scaled.reshape(-1, 1))[0][0]
    
    return f"Predicted Production: {prediction:.2f}"

# Create Gradio interface
demo = gr.Interface(
    fn=predict_production,
    inputs=[
        gr.Textbox(label="State Name"),
        gr.Textbox(label="District Name"),
        gr.Number(label="Crop Year"),
        gr.Textbox(label="Season"),
        gr.Textbox(label="Crop"),
        gr.Number(label="Area")
    ],
    outputs=gr.Textbox(label="Prediction"),
    title="Crop Production Predictor",
    description="Enter the crop details to predict production"
)

demo.launch()
